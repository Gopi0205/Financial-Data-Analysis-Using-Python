# %%
import datetime
from pandas_datareader import data
import yfinance as yf
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %%
# Ensure yfinance overrides pandas_datareader
yf.pdr_override()
# Out:
# yfinance: pandas_datareader support is deprecated & semi-broken so will be removed in a future verison. Just use yfinance.

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
# Fetch the data for Bank of America
BAC = data.get_data_yahoo('BAC', start=start, end=end)
#Citi Group
C = data.get_data_yahoo('C', start=start, end=end)
#Goldman sachs
GS = data.get_data_yahoo('GS', start=start, end=end)
#JPmorgan Chase
JPM = data.get_data_yahoo('JPM', start=start, end=end)
#Morgan Stanley
MS = data.get_data_yahoo('MS', start=start, end=end)
#Wells Fargo
WFC = data.get_data_yahoo('WFC', start=start, end=end)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
tickers = ['BAC','C','GS','JPM','MS','WFC']

# %%
bank_stocks = pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=tickers)

# %%
bank_stocks.head()
# Out:
#                   BAC                                                        \
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  31.943674  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  31.604424  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  31.645140  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  31.597647  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  31.618000  15619400
#
#                      C                                      ...         MS  \
#                   Open        High         Low       Close  ...        Low
# Date                                                        ...
# 2006-01-03  490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04  488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %%
bank_stocks.columns.names=['Bank Ticker','Stock Info']

# %%
bank_stocks.head()
# Out:
# Bank Ticker        BAC                                                        \
# Stock Info        Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03   46.919998  47.180000  46.150002  47.080002  31.943674  16296700
# 2006-01-04   47.000000  47.240002  46.450001  46.580002  31.604424  17757900
# 2006-01-05   46.580002  46.830002  46.320000  46.639999  31.645140  14970700
# 2006-01-06   46.799999  46.910000  46.349998  46.570000  31.597647  12599800
# 2006-01-09   46.720001  46.970001  46.360001  46.599998  31.618000  15619400
#
# Bank Ticker           C                                      ...         MS  \
# Stock Info         Open        High         Low       Close  ...        Low
# Date                                                         ...
# 2006-01-03   490.000000  493.799988  481.100006  492.899994  ...  56.740002
# 2006-01-04   488.600006  491.000000  483.500000  483.799988  ...  58.349998
# ...

# %%
for tick in tickers:
    print(tick,bank_stocks[tick]['Close'].max())
# Out:
# BAC 54.900001525878906
# C 564.0999755859375
# GS 247.9199981689453
# JPM 70.08000183105469
# MS 89.30000305175781
# WFC 58.52000045776367

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# WFC     58.520000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers:
    returns[tick+' Return']=bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2009-02-27
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2008-11-24
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BAC Return    0.036647
# C Return      0.038672
# GS Return     0.025390
# JPM Return    0.027667
# MS Return     0.037819
# WFC Return    0.030238
# dtype: float64

# %%
returns.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.001110
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005874
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586   -0.000158

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %%
morgan_stanley_2015_return = returns.loc['2015-01-01':'2015-12-31']['MS Return']
sns.distplot(morgan_stanley_2015_return,color='green',bins=50)
# Out:
# C:\Users\Gopi\AppData\Local\Temp\ipykernel_15556\2872847958.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(morgan_stanley_2015_return,color='green',bins=50)
# <Axes: xlabel='MS Return', ylabel='Density'>

# %%
ctitiMap_return_2008 = returns.loc['2008-01-01':'2008-12-31']['C Return']
sns.distplot(ctitiMap_return_2008,bins=50,color='red')
# Out:
# C:\Users\Gopi\AppData\Local\Temp\ipykernel_15556\2764259929.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ctitiMap_return_2008,bins=50,color='red')
# <Axes: xlabel='C Return', ylabel='Density'>

# %%
import plotly 
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plt.figure(figsize=(12,6))
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick)
plt.legend()

# %%
for tick in tickers:
    print(bank_stocks[tick]['Close'])
# Out:
# Date
# 2006-01-03    47.080002
# 2006-01-04    46.580002
# 2006-01-05    46.639999
# 2006-01-06    46.570000
# 2006-01-09    46.599998
#                 ...
# 2015-12-24    17.270000
# 2015-12-28    17.129999
# 2015-12-29    17.280001
# 2015-12-30    17.049999
# 2015-12-31    16.830000
# Name: Close, Length: 2517, dtype: float64
# Date
# 2006-01-03    492.899994
# 2006-01-04    483.799988
# 2006-01-05    486.200012
# 2006-01-06    486.200012
# 2006-01-09    483.899994
#                  ...
# 2015-12-24     52.709999
# 2015-12-28     52.380001
# 2015-12-29     52.980000
# 2015-12-30     52.299999
# 2015-12-31     51.750000
# Name: Close, Length: 2517, dtype: float64
# Date
# 2006-01-03    128.869995
# 2006-01-04    127.089996
# 2006-01-05    127.040001
# 2006-01-06    128.839996
# 2006-01-09    130.389999
#                  ...
# 2015-12-24    182.470001
# 2015-12-28    181.619995
# 2015-12-29    183.529999
# 2015-12-30    182.009995
# 2015-12-31    180.229996
# ...

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# C:\Users\Gopi\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.

# %%
plt.figure(figsize=(12,4))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label="30 Days Avg")
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC Close')
plt.legend()
plt.tight_layout()

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)
# Out:
# <Axes: xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)

# %%
close_corr = bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()
close_corr.iplot(kind='heatmap',colorscale='rdylbu')

# %%
bank_2015_2016 = BAC.loc['2015-01-01':'2016-01-01']
bank_2015_2016.iplot(kind='candle')
plt.tight_layout()

# %%
BAC
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2006-01-03  46.919998  47.180000  46.150002  47.080002  31.943674  16296700
# 2006-01-04  47.000000  47.240002  46.450001  46.580002  31.604424  17757900
# 2006-01-05  46.580002  46.830002  46.320000  46.639999  31.645140  14970700
# 2006-01-06  46.799999  46.910000  46.349998  46.570000  31.597647  12599800
# 2006-01-09  46.720001  46.970001  46.360001  46.599998  31.618000  15619400
# ...               ...        ...        ...        ...        ...       ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000  14.451782  29369400
# 2015-12-28  17.219999  17.230000  16.980000  17.129999  14.334625  41777500
# 2015-12-29  17.250000  17.350000  17.160000  17.280001  14.460152  45670400
# 2015-12-30  17.200001  17.240000  17.040001  17.049999  14.267678  35066400
# 2015-12-31  17.010000  17.070000  16.830000  16.830000  14.083584  47153000
#
# [2517 rows x 6 columns]

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma',periods=[13,21,56])
# Out:
# C:\Users\Gopi\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.

# %%
BAC['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='boll')
# Out:
# C:\Users\Gopi\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:117: FutureWarning:
#
# DatetimeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
